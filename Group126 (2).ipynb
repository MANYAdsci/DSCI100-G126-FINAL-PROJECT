# %% [markdown]
# # Iris Species Classification
#
# ### Group 126: Manya Jain, Zhuohang Lyu, Chang Sun

# %% [markdown]
# # Introduction

# %% [markdown]
# Iris is a genus of flowering plants with 310 recognised species with vivid flowers. Iris is both the common name and the scientific name for all species of Iris, as well as some species from other closely related genera.

# %% [markdown]
# ## Question:
# We shall answer the following question: Can we distinguish among the species of the iris plant?

# %% [markdown]
# ## Dataset Used:

# %% [markdown]
# The dataset that we will be using for the analysis is a multivariable dataset, “Iris flower dataset”, also known as “Fisher’s Iris data set”. The Iris dataset, which is also available on the UCI Machine Learning Repository, was utilised in R.A. Fisher's 1936 landmark paper ‘The Use of Multiple Measurements in Taxonomic Problems’.

# %% [markdown]
# It contains information about each flower's characteristics about three iris species (Iris setosa, Iris virginica and Iris versicolor)  with 50 samples each.

# %%
library(readxl)
library(tidyverse)
library(repr)
library(tidymodels)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.7     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# ── Attaching packages ────────────────────────────────────── tidymodels 1.0.0 ──
#
# ✔ broom        1.0.0     ✔ rsample      1.0.0
# ✔ dials        1.0.0     ✔ tune         1.0.0
# ✔ infer        1.0.2     ✔ workflows    1.0.0
# ✔ modeldata    1.0.0     ✔ workflowsets 1.0.0
# ✔ parsnip      1.0.0     ✔ yardstick    1.0.0
# ✔ recipes      1.0.1
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ yardstick::spec() masks readr::spec()
# ✖ recipes::step()   masks stats::step()
# • Use suppressPackageStartupMessages() to eliminate package startup messages

# %%
iris<- read.csv("data/Iris.csv")
iris<- mutate(iris, Species = as.factor(Species))|>
select(!Id)
iris
# Out:
#     SepalLengthCm SepalWidthCm PetalLengthCm PetalWidthCm Species
# 1   5.1           3.5          1.4           0.2          Iris-setosa
# 2   4.9           3.0          1.4           0.2          Iris-setosa
# 3   4.7           3.2          1.3           0.2          Iris-setosa
# 4   4.6           3.1          1.5           0.2          Iris-setosa
# 5   5.0           3.6          1.4           0.2          Iris-setosa
# 6   5.4           3.9          1.7           0.4          Iris-setosa
# 7   4.6           3.4          1.4           0.3          Iris-setosa
# 8   5.0           3.4          1.5           0.2          Iris-setosa
# 9   4.4           2.9          1.4           0.2          Iris-setosa
# 10  4.9           3.1          1.5           0.1          Iris-setosa
# 11  5.4           3.7          1.5           0.2          Iris-setosa
# 12  4.8           3.4          1.6           0.2          Iris-setosa
# 13  4.8           3.0          1.4           0.1          Iris-setosa
# 14  4.3           3.0          1.1           0.1          Iris-setosa
# 15  5.8           4.0          1.2           0.2          Iris-setosa
# 16  5.7           4.4          1.5           0.4          Iris-setosa
# 17  5.4           3.9          1.3           0.4          Iris-setosa
# 18  5.1           3.5          1.4           0.3          Iris-setosa
# 19  5.7           3.8          1.7           0.3          Iris-setosa
# 20  5.1           3.8          1.5           0.3          Iris-setosa
# 21  5.4           3.4          1.7           0.2          Iris-setosa
# 22  5.1           3.7          1.5           0.4          Iris-setosa
# 23  4.6           3.6          1.0           0.2          Iris-setosa
# 24  5.1           3.3          1.7           0.5          Iris-setosa
# 25  4.8           3.4          1.9           0.2          Iris-setosa
# 26  5.0           3.0          1.6           0.2          Iris-setosa
# 27  5.0           3.4          1.6           0.4          Iris-setosa
# 28  5.2           3.5          1.5           0.2          Iris-setosa
# 29  5.2           3.4          1.4           0.2          Iris-setosa
# 30  4.7           3.2          1.6           0.2          Iris-setosa
# ⋮   ⋮             ⋮            ⋮             ⋮            ⋮
# 121 6.9           3.2          5.7           2.3          Iris-virginica
# 122 5.6           2.8          4.9           2.0          Iris-virginica
# 123 7.7           2.8          6.7           2.0          Iris-virginica
# 124 6.3           2.7          4.9           1.8          Iris-virginica
# 125 6.7           3.3          5.7           2.1          Iris-virginica
# 126 7.2           3.2          6.0           1.8          Iris-virginica
# 127 6.2           2.8          4.8           1.8          Iris-virginica
# 128 6.1           3.0          4.9           1.8          Iris-virginica
# 129 6.4           2.8          5.6           2.1          Iris-virginica
# 130 7.2           3.0          5.8           1.6          Iris-virginica
# 131 7.4           2.8          6.1           1.9          Iris-virginica
# 132 7.9           3.8          6.4           2.0          Iris-virginica
# 133 6.4           2.8          5.6           2.2          Iris-virginica
# 134 6.3           2.8          5.1           1.5          Iris-virginica
# 135 6.1           2.6          5.6           1.4          Iris-virginica
# 136 7.7           3.0          6.1           2.3          Iris-virginica
# 137 6.3           3.4          5.6           2.4          Iris-virginica
# 138 6.4           3.1          5.5           1.8          Iris-virginica
# 139 6.0           3.0          4.8           1.8          Iris-virginica
# 140 6.9           3.1          5.4           2.1          Iris-virginica
# 141 6.7           3.1          5.6           2.4          Iris-virginica
# 142 6.9           3.1          5.1           2.3          Iris-virginica
# 143 5.8           2.7          5.1           1.9          Iris-virginica
# 144 6.8           3.2          5.9           2.3          Iris-virginica
# 145 6.7           3.3          5.7           2.5          Iris-virginica
# 146 6.7           3.0          5.2           2.3          Iris-virginica
# 147 6.3           2.5          5.0           1.9          Iris-virginica
# 148 6.5           3.0          5.2           2.0          Iris-virginica
# 149 6.2           3.4          5.4           2.3          Iris-virginica
# 150 5.9           3.0          5.1           1.8          Iris-virginica

# %%
iris_split <- initial_split(iris, prop= 0.8, strata= Species)
iris_train <- training(iris_split)
iris_test <- testing(iris_split)

# %%
set.seed(200)

iris_recipe <- recipe(Species ~., data = iris_train) %>%
    step_scale(all_predictors()) %>%
    step_center(all_predictors())

knn_spec<-nearest_neighbor(weight_func = "rectangular", neighbors = tune())|>
set_engine("kknn")|>
set_mode("classification")

iris_vfold<-vfold_cv(iris_train,v=5,strata=Species)

gridvals<-tibble(neighbors = seq(1,91))

iris_results<-workflow()|>
add_recipe(iris_recipe)|>
add_model(knn_spec)|>
tune_grid(resamples = iris_vfold, grid=gridvals)|>
collect_metrics()
iris_results
# Out:
#     neighbors .metric  .estimator mean      n std_err     .config
# 1    1        accuracy multiclass 0.9500000 5 0.024295633 Preprocessor1_Model01
# 2    1        roc_auc  hand_till  0.9625000 5 0.018221725 Preprocessor1_Model01
# 3    2        accuracy multiclass 0.9500000 5 0.024295633 Preprocessor1_Model02
# 4    2        roc_auc  hand_till  0.9700521 5 0.010705627 Preprocessor1_Model02
# 5    3        accuracy multiclass 0.9500000 5 0.020412415 Preprocessor1_Model03
# 6    3        roc_auc  hand_till  0.9890625 5 0.008454522 Preprocessor1_Model03
# 7    4        accuracy multiclass 0.9500000 5 0.020412415 Preprocessor1_Model04
# 8    4        roc_auc  hand_till  0.9885417 5 0.007663510 Preprocessor1_Model04
# 9    5        accuracy multiclass 0.9333333 5 0.016666667 Preprocessor1_Model05
# 10   5        roc_auc  hand_till  0.9864583 5 0.008613456 Preprocessor1_Model05
# 11   6        accuracy multiclass 0.9333333 5 0.016666667 Preprocessor1_Model06
# 12   6        roc_auc  hand_till  0.9911458 5 0.004000597 Preprocessor1_Model06
# 13   7        accuracy multiclass 0.9500000 5 0.015590239 Preprocessor1_Model07
# 14   7        roc_auc  hand_till  0.9942708 5 0.002899877 Preprocessor1_Model07
# 15   8        accuracy multiclass 0.9500000 5 0.015590239 Preprocessor1_Model08
# 16   8        roc_auc  hand_till  0.9937500 5 0.002681154 Preprocessor1_Model08
# 17   9        accuracy multiclass 0.9500000 5 0.020412415 Preprocessor1_Model09
# 18   9        roc_auc  hand_till  0.9963542 5 0.001948780 Preprocessor1_Model09
# 19  10        accuracy multiclass 0.9500000 5 0.020412415 Preprocessor1_Model10
# 20  10        roc_auc  hand_till  0.9958333 5 0.001948780 Preprocessor1_Model10
# 21  11        accuracy multiclass 0.9500000 5 0.024295633 Preprocessor1_Model11
# 22  11        roc_auc  hand_till  0.9953125 5 0.002524833 Preprocessor1_Model11
# 23  12        accuracy multiclass 0.9500000 5 0.024295633 Preprocessor1_Model12
# 24  12        roc_auc  hand_till  0.9942708 5 0.002240189 Preprocessor1_Model12
# 25  13        accuracy multiclass 0.9333333 5 0.010206207 Preprocessor1_Model13
# 26  13        roc_auc  hand_till  0.9937500 5 0.002415005 Preprocessor1_Model13
# 27  14        accuracy multiclass 0.9333333 5 0.010206207 Preprocessor1_Model14
# 28  14        roc_auc  hand_till  0.9921875 5 0.002178802 Preprocessor1_Model14
# 29  15        accuracy multiclass 0.9500000 5 0.008333333 Preprocessor1_Model15
# 30  15        roc_auc  hand_till  0.9958333 5 0.001041667 Preprocessor1_Model15
# ⋮   ⋮         ⋮        ⋮          ⋮         ⋮ ⋮           ⋮
# 153 77        accuracy multiclass 0.7916667 5 0.058925565 Preprocessor1_Model77
# 154 77        roc_auc  hand_till  0.8424479 5 0.031328569 Preprocessor1_Model77
# 155 78        accuracy multiclass 0.7916667 5 0.058925565 Preprocessor1_Model78
# 156 78        roc_auc  hand_till  0.8424479 5 0.031328569 Preprocessor1_Model78
# 157 79        accuracy multiclass 0.7916667 5 0.058925565 Preprocessor1_Model79
# 158 79        roc_auc  hand_till  0.8372396 5 0.028506408 Preprocessor1_Model79
# 159 80        accuracy multiclass 0.7916667 5 0.058925565 Preprocessor1_Model80
# 160 80        roc_auc  hand_till  0.8364583 5 0.029773610 Preprocessor1_Model80
# 161 81        accuracy multiclass 0.7916667 5 0.058925565 Preprocessor1_Model81
# 162 81        roc_auc  hand_till  0.8385417 5 0.030246474 Preprocessor1_Model81
# 163 82        accuracy multiclass 0.7916667 5 0.058925565 Preprocessor1_Model82
# 164 82        roc_auc  hand_till  0.8322917 5 0.030084607 Preprocessor1_Model82
# 165 83        accuracy multiclass 0.7916667 5 0.058925565 Preprocessor1_Model83
# 166 83        roc_auc  hand_till  0.8309896 5 0.030576510 Preprocessor1_Model83
# 167 84        accuracy multiclass 0.7916667 5 0.058925565 Preprocessor1_Model84
# 168 84        roc_auc  hand_till  0.8341146 5 0.026254340 Preprocessor1_Model84
# 169 85        accuracy multiclass 0.7916667 5 0.058925565 Preprocessor1_Model85
# 170 85        roc_auc  hand_till  0.8367187 5 0.022430629 Preprocessor1_Model85
# 171 86        accuracy multiclass 0.7916667 5 0.058925565 Preprocessor1_Model86
# 172 86        roc_auc  hand_till  0.8346354 5 0.020727269 Preprocessor1_Model86
# 173 87        accuracy multiclass 0.7916667 5 0.058925565 Preprocessor1_Model87
# 174 87        roc_auc  hand_till  0.8322917 5 0.021750639 Preprocessor1_Model87
# 175 88        accuracy multiclass 0.7916667 5 0.058925565 Preprocessor1_Model88
# 176 88        roc_auc  hand_till  0.8187500 5 0.018147137 Preprocessor1_Model88
# 177 89        accuracy multiclass 0.7916667 5 0.058925565 Preprocessor1_Model89
# 178 89        roc_auc  hand_till  0.8125000 5 0.014452538 Preprocessor1_Model89
# 179 90        accuracy multiclass 0.7916667 5 0.058925565 Preprocessor1_Model90
# 180 90        roc_auc  hand_till  0.8020833 5 0.008558165 Preprocessor1_Model90
# 181 91        accuracy multiclass 0.7916667 5 0.058925565 Preprocessor1_Model91
# 182 91        roc_auc  hand_till  0.7963542 5 0.010812781 Preprocessor1_Model91

# %%
iris_val_plot<-iris_results|>
ggplot(aes(x = neighbors,y=mean))+
geom_point()+
labs(x="Neighbors",y="Accuracy Estimate")+
theme(text = element_text(size = 20))
iris_val_plot
# Out:
# plot without title

# %%
knn_best_spec<-nearest_neighbor(weight_func = "rectangular", neighbors = 25)|>
set_engine("kknn")|>
set_mode("classification")

iris_fit<-workflow()|>
add_recipe(iris_recipe)|>
add_model(knn_best_spec)|>
fit(data=iris_train)

# %%
iris_predictions<- predict(iris_fit,iris_test)|>
bind_cols(iris_test)
iris_predictions
# Out:
#    .pred_class     SepalLengthCm SepalWidthCm PetalLengthCm PetalWidthCm
# 1  Iris-setosa     4.9           3.0          1.4           0.2
# 2  Iris-setosa     4.6           3.1          1.5           0.2
# 3  Iris-setosa     5.0           3.4          1.5           0.2
# 4  Iris-setosa     5.1           3.7          1.5           0.4
# 5  Iris-setosa     5.1           3.3          1.7           0.5
# 6  Iris-setosa     4.8           3.4          1.9           0.2
# 7  Iris-setosa     5.2           3.4          1.4           0.2
# 8  Iris-setosa     5.4           3.4          1.5           0.4
# 9  Iris-setosa     5.2           4.1          1.5           0.1
# 10 Iris-setosa     4.4           3.2          1.3           0.2
# 11 Iris-versicolor 7.0           3.2          4.7           1.4
# 12 Iris-versicolor 6.4           3.2          4.5           1.5
# 13 Iris-versicolor 5.5           2.3          4.0           1.3
# 14 Iris-versicolor 5.9           3.0          4.2           1.5
# 15 Iris-versicolor 5.7           2.6          3.5           1.0
# 16 Iris-versicolor 5.5           2.4          3.7           1.0
# 17 Iris-versicolor 5.6           3.0          4.1           1.3
# 18 Iris-versicolor 5.5           2.5          4.0           1.3
# 19 Iris-versicolor 5.0           2.3          3.3           1.0
# 20 Iris-versicolor 5.7           2.8          4.1           1.3
# 21 Iris-virginica  7.1           3.0          5.9           2.1
# 22 Iris-virginica  6.5           3.0          5.8           2.2
# 23 Iris-versicolor 4.9           2.5          4.5           1.7
# 24 Iris-virginica  6.7           2.5          5.8           1.8
# 25 Iris-virginica  6.4           2.7          5.3           1.9
# 26 Iris-virginica  6.3           2.7          4.9           1.8
# 27 Iris-virginica  7.2           3.2          6.0           1.8
# 28 Iris-virginica  6.3           3.4          5.6           2.4
# 29 Iris-virginica  6.9           3.1          5.1           2.3
# 30 Iris-virginica  6.2           3.4          5.4           2.3
#    Species
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa
# 5  Iris-setosa
# 6  Iris-setosa
# 7  Iris-setosa
# 8  Iris-setosa
# 9  Iris-setosa
# 10 Iris-setosa
# 11 Iris-versicolor
# 12 Iris-versicolor
# 13 Iris-versicolor
# 14 Iris-versicolor
# 15 Iris-versicolor
# 16 Iris-versicolor
# 17 Iris-versicolor
# 18 Iris-versicolor
# 19 Iris-versicolor
# 20 Iris-versicolor
# 21 Iris-virginica
# 22 Iris-virginica
# 23 Iris-virginica
# 24 Iris-virginica
# 25 Iris-virginica
# 26 Iris-virginica
# 27 Iris-virginica
# 28 Iris-virginica
# 29 Iris-virginica
# 30 Iris-virginica

# %%
iris_accuracy<-iris_predictions|>
metrics(truth= Species,estimate=.pred_class)|>
select(.metric,.estimate)|>
head(1)
iris_accuracy
# Out:
#   .metric  .estimate
# 1 accuracy 0.9666667

# %%
iris_cm<-iris_predictions|>
conf_mat(truth = Species,estimate=.pred_class)
iris_cm
# Out:
#                  Truth
# Prediction        Iris-setosa Iris-versicolor Iris-virginica
#   Iris-setosa              10               0              0
#   Iris-versicolor           0              10              1
#   Iris-virginica            0               0              9

# %% [markdown]
# # Methods

# %% [markdown]
# We intend to perform classification by stratifying the dataset by species.

# %% [markdown]
#  These are the columns in this dataset:

# %% [markdown]
# * Id
# * SepalLengthCm
# * SepalWidthCm
# * PetalLengthCm
# * PetalWidthCm
# * Species

# %% [markdown]
# The predictors we will be using are: SepalLengthCm, SepalWidthCm, PetalLengthCm and PetalWidthCm.
# We will visualize using scatter plot: In order to investigate the relationship between individual predictors based on iris species, scatterplot may be a better choice because the scatterplot is a type of data display that demonstrates the connection between two numerical variables.

# %% [markdown]
# # Expected outcomes and significance:

# %% [markdown]
# In this project we expect to be able to identify the species of iris by the shape of its sepals and petals (length and width). Based on this data, more species of iris can be identified, which may facilitate the selecting and breeding of better varieties.
